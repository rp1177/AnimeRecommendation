# %% [markdown]
# ### MyAniMate: Anime Recommendation System

# %%
#Import the necessary libraries: 
import pandas as pd
import numpy as np
import json
import re 
import sys
import itertools

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns

import nltk
import nltk.corpus
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt')

from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\saiya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\saiya\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\saiya\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\saiya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# #### 1.) Data Observations and Clean Up

# %% [markdown]
# Data retrieved from: https://www.kaggle.com/datasets/dbdmobile/myanimelist-dataset/data . The data is from myAnimeList
#
# First, we will observe the characteristics of this data and jot down our observations by converting the following CSV file into a Pandas DataFrame.

# %%
animedf = pd.read_csv('anime-dataset-2023.csv')
animedf
# Out:
#        anime_id                             Name             English name  \
# 0             1                     Cowboy Bebop             Cowboy Bebop
# 1             5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2             6                           Trigun                   Trigun
# 3             7               Witch Hunter Robin       Witch Hunter Robin
# 4             8                   Bouken Ou Beet   Beet the Vandel Buster
# ...         ...                              ...                      ...
# 24900     55731                      Wu Nao Monu                  UNKNOWN
# 24901     55732              Bu Xing Si: Yuan Qi              Blader Soul
# 24902     55733                      Di Yi Xulie          The First Order
# 24903     55734         Bokura no Saishuu Sensou                  UNKNOWN
# 24904     55735                   Shijuuku Nichi                  UNKNOWN
#
#                              Other name    Score  \
# 0                             カウボーイビバップ     8.75
# 1                        カウボーイビバップ 天国の扉     8.38
# 2                                 トライガン     8.22
# 3      Witch Hunter ROBIN (ウイッチハンターロビン)     7.25
# 4                                冒険王ビィト     6.94
# ...                                 ...      ...
# 24900                              无脑魔女  UNKNOWN
# 24901                            捕星司·源起  UNKNOWN
# 24902                              第一序列  UNKNOWN
# 24903                           僕らの最終戦争  UNKNOWN
# 24904                              四十九日  UNKNOWN
#
#                                      Genres  \
# 0             Action, Award Winning, Sci-Fi
# 1                            Action, Sci-Fi
# 2                 Action, Adventure, Sci-Fi
# 3      Action, Drama, Mystery, Supernatural
# 4          Adventure, Fantasy, Supernatural
# ...                                     ...
# 24900        Comedy, Fantasy, Slice of Life
# 24901            Action, Adventure, Fantasy
# 24902    Action, Adventure, Fantasy, Sci-Fi
# 24903                               UNKNOWN
# 24904                               UNKNOWN
#
#                                                 Synopsis   Type Episodes  \
# 0      Crime is timeless. By the year 2071, humanity ...     TV     26.0
# 1      Another day, another bounty—such is the life o...  Movie      1.0
# 2      Vash the Stampede is the man with a $$60,000,0...     TV     26.0
# 3      Robin Sena is a powerful craft user drafted in...     TV     26.0
# 4      It is the dark century and the people are suff...     TV     52.0
# ...                                                  ...    ...      ...
# 24900           No description available for this anime.    ONA     15.0
# 24901           No description available for this anime.    ONA     18.0
# 24902           No description available for this anime.    ONA     16.0
# 24903  A music video for the song Bokura no Saishuu S...  Music      1.0
# 24904  A music video for the song Shijuuku Nichi by S...  Music      1.0
#
#                               Aired  ...         Studios     Source  \
# 0       Apr 3, 1998 to Apr 24, 1999  ...         Sunrise   Original
# 1                       Sep 1, 2001  ...           Bones   Original
# 2       Apr 1, 1998 to Sep 30, 1998  ...        Madhouse      Manga
# 3       Jul 3, 2002 to Dec 25, 2002  ...         Sunrise   Original
# 4      Sep 30, 2004 to Sep 29, 2005  ...  Toei Animation      Manga
# ...                             ...  ...             ...        ...
# 24900              Jul 4, 2023 to ?  ...         UNKNOWN  Web manga
# 24901             Jul 27, 2023 to ?  ...         UNKNOWN  Web novel
# 24902             Jul 19, 2023 to ?  ...         UNKNOWN  Web novel
# 24903                  Apr 23, 2022  ...         UNKNOWN   Original
# 24904                   Sep 5, 2022  ...         UNKNOWN   Original
#
#             Duration                          Rating     Rank Popularity  \
# 0      24 min per ep  R - 17+ (violence & profanity)     41.0         43
# 1        1 hr 55 min  R - 17+ (violence & profanity)    189.0        602
# 2      24 min per ep       PG-13 - Teens 13 or older    328.0        246
# 3      25 min per ep       PG-13 - Teens 13 or older   2764.0       1795
# 4      23 min per ep                   PG - Children   4240.0       5126
# ...              ...                             ...      ...        ...
# 24900        Unknown       PG-13 - Teens 13 or older  UNKNOWN      24723
# 24901        Unknown       PG-13 - Teens 13 or older      0.0          0
# 24902        Unknown       PG-13 - Teens 13 or older      0.0          0
# 24903          3 min       PG-13 - Teens 13 or older      0.0          0
# 24904          3 min       PG-13 - Teens 13 or older      0.0          0
#
#       Favorites Scored By  Members  \
# 0         78525  914193.0  1771505
# 1          1448  206248.0   360978
# 2         15035  356739.0   727252
# 3           613   42829.0   111931
# 4            14    6413.0    15001
# ...         ...       ...      ...
# 24900         0   UNKNOWN        0
# 24901         0   UNKNOWN        0
# 24902         0   UNKNOWN        0
# 24903         0   UNKNOWN        0
# 24904         0   UNKNOWN        0
#
#                                                Image URL
# 0      https://cdn.myanimelist.net/images/anime/4/196...
# 1      https://cdn.myanimelist.net/images/anime/1439/...
# 2      https://cdn.myanimelist.net/images/anime/7/203...
# 3      https://cdn.myanimelist.net/images/anime/10/19...
# 4      https://cdn.myanimelist.net/images/anime/7/215...
# ...                                                  ...
# 24900  https://cdn.myanimelist.net/images/anime/1386/...
# 24901  https://cdn.myanimelist.net/images/anime/1383/...
# 24902  https://cdn.myanimelist.net/images/anime/1130/...
# 24903  https://cdn.myanimelist.net/images/anime/1931/...
# 24904  https://cdn.myanimelist.net/images/anime/1902/...
#
# [24905 rows x 24 columns]

# %%
animedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24905 entries, 0 to 24904
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   anime_id      24905 non-null  int64
#  1   Name          24905 non-null  object
#  2   English name  24905 non-null  object
#  3   Other name    24905 non-null  object
#  4   Score         24905 non-null  object
#  5   Genres        24905 non-null  object
#  6   Synopsis      24905 non-null  object
#  7   Type          24905 non-null  object
#  8   Episodes      24905 non-null  object
#  9   Aired         24905 non-null  object
#  10  Premiered     24905 non-null  object
#  11  Status        24905 non-null  object
#  12  Producers     24905 non-null  object
#  13  Licensors     24905 non-null  object
#  14  Studios       24905 non-null  object
#  15  Source        24905 non-null  object
#  16  Duration      24905 non-null  object
#  17  Rating        24905 non-null  object
#  18  Rank          24905 non-null  object
#  19  Popularity    24905 non-null  int64
#  20  Favorites     24905 non-null  int64
#  21  Scored By     24905 non-null  object
#  22  Members       24905 non-null  int64
#  23  Image URL     24905 non-null  object
# dtypes: int64(4), object(20)
# memory usage: 4.6+ MB

# %%
#Lets understand what kind of columns we have. We only need certain kinds of columns to gain important info for our rec system
animedf.columns
# Out:
# Index(['anime_id', 'Name', 'English name', 'Other name', 'Score', 'Genres',
#        'Synopsis', 'Type', 'Episodes', 'Aired', 'Premiered', 'Status',
#        'Producers', 'Licensors', 'Studios', 'Source', 'Duration', 'Rating',
#        'Rank', 'Popularity', 'Favorites', 'Scored By', 'Members', 'Image URL'],
#       dtype='object')

# %%
#Convert Score, Scored by, Favorites into int and floats:

animedf['Score'] = animedf['Score'].replace(to_replace='UNKNOWN', value=None)
animedf['Score'] = animedf['Score'].astype(float)

animedf['Scored By'] = animedf['Scored By'].replace(to_replace='UNKNOWN', value=None)
animedf['Scored By'] = animedf['Scored By'].astype(float)


animedf['Favorites'] = animedf['Favorites'].astype(int)

# %%
animedf['Type'] #type columns indicates if its a movie or tv show.
# Out:
# 0           TV
# 1        Movie
# 2           TV
# 3           TV
# 4           TV
#          ...
# 24900      ONA
# 24901      ONA
# 24902      ONA
# 24903    Music
# 24904    Music
# Name: Type, Length: 24905, dtype: object

# %%
animedf['Type'].value_counts()
# Out:
# Type
# TV         7597
# Movie      4381
# OVA        4076
# ONA        3533
# Music      2686
# Special    2558
# UNKNOWN      74
# Name: count, dtype: int64

# %% [markdown]
# Here we are exploring the "Type" column more in-depth because we want our anime recommendation system to only focus on TV, Movie, OVA, ONA and Specials. We notice here that we have "UNKNOWNS" and "MUSIC" which in a content based recommendation system may not be as significant to the anime experience. We may need to perform some data cleaning and keep necessary information columns to help build our recommendation system.

# %%
#Check for null values:
animedf.isnull().sum() #We may be seeing more 0s because we didn't fix up the "UNKNOWNS" and missing descriptions.
# Out:
# anime_id           0
# Name               0
# English name       0
# Other name         0
# Score           9213
# Genres             0
# Synopsis           0
# Type               0
# Episodes           0
# Aired              0
# Premiered          0
# Status             0
# Producers          0
# Licensors          0
# Studios            0
# Source             0
# Duration           0
# Rating             0
# Rank               0
# Popularity         0
# Favorites          0
# Scored By       9213
# Members            0
# Image URL          0
# dtype: int64

# %%
animedf.head()
# Out:
#    anime_id                             Name             English name  \
# 0         1                     Cowboy Bebop             Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2         6                           Trigun                   Trigun
# 3         7               Witch Hunter Robin       Witch Hunter Robin
# 4         8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                          Other name  Score  \
# 0                         カウボーイビバップ   8.75
# 1                    カウボーイビバップ 天国の扉   8.38
# 2                             トライガン   8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)   7.25
# 4                            冒険王ビィト   6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
#                                             Synopsis   Type Episodes  \
# 0  Crime is timeless. By the year 2071, humanity ...     TV     26.0
# 1  Another day, another bounty—such is the life o...  Movie      1.0
# 2  Vash the Stampede is the man with a $$60,000,0...     TV     26.0
# 3  Robin Sena is a powerful craft user drafted in...     TV     26.0
# 4  It is the dark century and the people are suff...     TV     52.0
#
#                           Aired  ...         Studios    Source       Duration  \
# 0   Apr 3, 1998 to Apr 24, 1999  ...         Sunrise  Original  24 min per ep
# 1                   Sep 1, 2001  ...           Bones  Original    1 hr 55 min
# 2   Apr 1, 1998 to Sep 30, 1998  ...        Madhouse     Manga  24 min per ep
# 3   Jul 3, 2002 to Dec 25, 2002  ...         Sunrise  Original  25 min per ep
# 4  Sep 30, 2004 to Sep 29, 2005  ...  Toei Animation     Manga  23 min per ep
#
#                            Rating    Rank Popularity Favorites Scored By  \
# 0  R - 17+ (violence & profanity)    41.0         43     78525  914193.0
# 1  R - 17+ (violence & profanity)   189.0        602      1448  206248.0
# 2       PG-13 - Teens 13 or older   328.0        246     15035  356739.0
# 3       PG-13 - Teens 13 or older  2764.0       1795       613   42829.0
# 4                   PG - Children  4240.0       5126        14    6413.0
#
#    Members                                          Image URL
# 0  1771505  https://cdn.myanimelist.net/images/anime/4/196...
# 1   360978  https://cdn.myanimelist.net/images/anime/1439/...
# 2   727252  https://cdn.myanimelist.net/images/anime/7/203...
# 3   111931  https://cdn.myanimelist.net/images/anime/10/19...
# 4    15001  https://cdn.myanimelist.net/images/anime/7/215...
#
# [5 rows x 24 columns]

# %% [markdown]
# So far, we can indicate the name, score, scored by, genre type, synopsis (summary), type, rating, and favorites. Popularity and rank might be redundant here and might lead to multicollinearity. I believe these will be the most necessary columns in order to build the recommender system. For now we will also keep anime_id if we need to reference back to a unique case or outlier. But it will not be included in the model.

# %% [markdown]
# ##### Other observations on data before cleaning:

# %% [markdown]
# 1.) Dataset focuses on the anime type and its other characteristics such as episode amount, release date, studio creation, etc. It provides in-depth information on the anime listed.
#
# 2.) We may face limitations due to the dataset being focused on the 2023 lineup of data in MyAnimeList and may not be up to date as well as its a dataset from Kaggle. It may not reflect current anime trends today but understand anime trends last year among users on that website.
#
# 3.) All of the column values are objects.

# %%
#Now lets clean up our data to keep relevant features. Do this by making new df called animedf_clean

#1. Drop the "English Name" and "Other Name" as well as other unnecessary columns. We notice that "English Name" has "UNKNOWNS" Listed. So we should keep "Name" only. 
animedf_clean = animedf.drop(['Other name', 'Episodes','Duration','Rank','Popularity','Members', 'Premiered', 'Aired', 'Status'], axis=1)
animedf_clean
# Out:
#        anime_id                             Name             English name  \
# 0             1                     Cowboy Bebop             Cowboy Bebop
# 1             5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2             6                           Trigun                   Trigun
# 3             7               Witch Hunter Robin       Witch Hunter Robin
# 4             8                   Bouken Ou Beet   Beet the Vandel Buster
# ...         ...                              ...                      ...
# 24900     55731                      Wu Nao Monu                  UNKNOWN
# 24901     55732              Bu Xing Si: Yuan Qi              Blader Soul
# 24902     55733                      Di Yi Xulie          The First Order
# 24903     55734         Bokura no Saishuu Sensou                  UNKNOWN
# 24904     55735                   Shijuuku Nichi                  UNKNOWN
#
#        Score                                Genres  \
# 0       8.75         Action, Award Winning, Sci-Fi
# 1       8.38                        Action, Sci-Fi
# 2       8.22             Action, Adventure, Sci-Fi
# 3       7.25  Action, Drama, Mystery, Supernatural
# 4       6.94      Adventure, Fantasy, Supernatural
# ...      ...                                   ...
# 24900    NaN        Comedy, Fantasy, Slice of Life
# 24901    NaN            Action, Adventure, Fantasy
# 24902    NaN    Action, Adventure, Fantasy, Sci-Fi
# 24903    NaN                               UNKNOWN
# 24904    NaN                               UNKNOWN
#
#                                                 Synopsis   Type  \
# 0      Crime is timeless. By the year 2071, humanity ...     TV
# 1      Another day, another bounty—such is the life o...  Movie
# 2      Vash the Stampede is the man with a $$60,000,0...     TV
# 3      Robin Sena is a powerful craft user drafted in...     TV
# 4      It is the dark century and the people are suff...     TV
# ...                                                  ...    ...
# 24900           No description available for this anime.    ONA
# 24901           No description available for this anime.    ONA
# 24902           No description available for this anime.    ONA
# 24903  A music video for the song Bokura no Saishuu S...  Music
# 24904  A music video for the song Shijuuku Nichi by S...  Music
#
#                                                Producers  \
# 0                                          Bandai Visual
# 1                                 Sunrise, Bandai Visual
# 2                                   Victor Entertainment
# 3      Bandai Visual, Dentsu, Victor Entertainment, T...
# 4                                       TV Tokyo, Dentsu
# ...                                                  ...
# 24900                                            UNKNOWN
# 24901                                            UNKNOWN
# 24902                                            UNKNOWN
# 24903                                            UNKNOWN
# 24904                                            UNKNOWN
#
#                                   Licensors         Studios     Source  \
# 0          Funimation, Bandai Entertainment         Sunrise   Original
# 1               Sony Pictures Entertainment           Bones   Original
# 2      Funimation, Geneon Entertainment USA        Madhouse      Manga
# 3          Funimation, Bandai Entertainment         Sunrise   Original
# 4                  Illumitoon Entertainment  Toei Animation      Manga
# ...                                     ...             ...        ...
# 24900                               UNKNOWN         UNKNOWN  Web manga
# 24901                               UNKNOWN         UNKNOWN  Web novel
# 24902                               UNKNOWN         UNKNOWN  Web novel
# 24903                               UNKNOWN         UNKNOWN   Original
# 24904                               UNKNOWN         UNKNOWN   Original
#
#                                Rating  Favorites  Scored By  \
# 0      R - 17+ (violence & profanity)      78525   914193.0
# 1      R - 17+ (violence & profanity)       1448   206248.0
# 2           PG-13 - Teens 13 or older      15035   356739.0
# 3           PG-13 - Teens 13 or older        613    42829.0
# 4                       PG - Children         14     6413.0
# ...                               ...        ...        ...
# 24900       PG-13 - Teens 13 or older          0        NaN
# 24901       PG-13 - Teens 13 or older          0        NaN
# 24902       PG-13 - Teens 13 or older          0        NaN
# 24903       PG-13 - Teens 13 or older          0        NaN
# 24904       PG-13 - Teens 13 or older          0        NaN
#
#                                                Image URL
# 0      https://cdn.myanimelist.net/images/anime/4/196...
# 1      https://cdn.myanimelist.net/images/anime/1439/...
# 2      https://cdn.myanimelist.net/images/anime/7/203...
# 3      https://cdn.myanimelist.net/images/anime/10/19...
# 4      https://cdn.myanimelist.net/images/anime/7/215...
# ...                                                  ...
# 24900  https://cdn.myanimelist.net/images/anime/1386/...
# 24901  https://cdn.myanimelist.net/images/anime/1383/...
# 24902  https://cdn.myanimelist.net/images/anime/1130/...
# 24903  https://cdn.myanimelist.net/images/anime/1931/...
# 24904  https://cdn.myanimelist.net/images/anime/1902/...
#
# [24905 rows x 15 columns]

# %%
animedf_clean['Synopsis'].tail(50)
# Out:
# 24855          Music video for the song TRIPPER by Kankan.
# 24856    Music video for the song Fins by Tsunomaki Wat...
# 24857             No description available for this anime.
# 24858    Music video for the song Twilight (#1 Abstract...
# 24859             No description available for this anime.
# 24860    Music video for the song Sayonara Wonderland b...
# 24861    In the majestic fantasy world, how does the pr...
# 24862    Music video for the song Denki Groove 30-shuun...
# 24863     Music video for the song Gin Kkum by SE SO NEON.
# 24864    Music video for the song Another day, another ...
# 24865    Music video for the original song Baka Bakka b...
# 24866             No description available for this anime.
# 24867      Second season of Boku no Kokoro no Yabai Yatsu.
# 24868    Seiichi is bored with his routine life as a te...
# 24869             No description available for this anime.
# 24870             No description available for this anime.
# 24871             No description available for this anime.
# 24872    Music video for the song Move On by Doppelgenger.
# 24873    Music video for the song You're so lonely now,...
# 24874             No description available for this anime.
# 24875             Hashira Training Arc of Kimetsu no Yaiba
# 24876                    Fourth season of Kimetsu no Yaiba
# 24877    A short mini movie meant to celebrate the endi...
# 24878    Music video for the song Fight Club by Kenmoch...
# 24879     Music video for the song Music by Kuusou Iinkai.
# 24880        Music video for the song Kokoro by Shikidrop.
# 24881    Music video for the song Nazukeau Tabiji by Sh...
# 24882                 The movie version of Boku to Roboko.
# 24883    The "Hana Ningyou Project" (Flower Doll Projec...
# 24884    A "remix version" of Modern with a soundtrack ...
# 24885    Set in a mechanical world, Mechronicle tells t...
# 24886    A boy named Allen was unable to receive the gi...
# 24887    "If you're not my rival, why do I feel this wa...
# 24888    I wanted to die.. until I met him.\nAfter brea...
# 24889    A collaboration anime between Genjitsu no Yoha...
# 24890             No description available for this anime.
# 24891    html.serialization_informationFIN.\nジャンル\nFant...
# 24892    I'm the daughter of a Duke?!\nWhile locked up ...
# 24893    Haeun is a nobleman who falls hard for Dullseh...
# 24894    Wanna fake-date for 4 weeks?\nDojun's life at ...
# 24895    I just want to tell him how I feel!\nMina has ...
# 24896             No description available for this anime.
# 24897    Music video for the song Wo Mengjian ni Mengji...
# 24898         Music video for the song Thailand by Oh Shu.
# 24899    Music video for the song Energy by SLEEQ (Kim ...
# 24900             No description available for this anime.
# 24901             No description available for this anime.
# 24902             No description available for this anime.
# 24903    A music video for the song Bokura no Saishuu S...
# 24904    A music video for the song Shijuuku Nichi by S...
# Name: Synopsis, dtype: object

# %%
#Filter and remove "UNKNOWN" and "Music" types we only want our recommender system to recommend users movies, tv shows, specials, etc.
animedf_clean = animedf_clean[(animedf_clean['Type'] != 'UNKNOWN') & (animedf_clean['Type'] != 'Music')]
animedf_clean['Type'].value_counts()
# Out:
# Type
# TV         7597
# Movie      4381
# OVA        4076
# ONA        3533
# Special    2558
# Name: count, dtype: int64

# %% [markdown]
# After filtering out the types, we should check if our genres and synopsis are unknown or include no description. If these are left in our recommendation system, we will face issues with our actual recommendations. To do so, let's illustrate the unknown values and ensure they are randomly distributed (via Heatmap). If they are, we can remove them but if they aren't, we may need to impute or modify them.

# %%
#Replace Synopsis and other columns that are missing with '':
animedf_clean['Synopsis'] = animedf_clean['Synopsis'].replace(to_replace='No description available for this anime.', value='')

#Replace other column values that are 'UNKNOWN' to '':
animedf_clean = animedf_clean.replace(to_replace='UNKNOWN', value='')

animedf_clean = animedf_clean.replace(to_replace='\n', value='')
# Out:
# C:\Users\saiya\AppData\Local\Temp\ipykernel_1980\2327155648.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   animedf_clean['Synopsis'] = animedf_clean['Synopsis'].replace(to_replace='No description available for this anime.', value='')

# %%
#Lets try merging the name and english name columns:

animedf_clean['English name'] = animedf_clean['English name'].replace(to_replace='', value=None)
animedf_clean['English name'] = animedf_clean['English name'].fillna(animedf_clean['Name'])
#animedf_clean['Names'] = animedf_clean['Name'] + ' ' + animedf_clean['English name']

animedf_clean.tail(50)
# Out:
#        anime_id                                               Name  \
# 24804     55607                                    Cannibal Seijin
# 24805     55608                                             Maehwa
# 24806     55609                              Chouetsu Jin Shinriki
# 24807     55610                                           Souseiki
# 24808     55611                        Watashi no shinri jissen-ki
# 24809     55612                                Hikari: Be My Light
# 24812     55615              BECOME THE CASTELLAN IN ANOTHER WORLD
# 24813     55616                       Fuufu Koukan: Modorenai Yoru
# 24815     55618                            Milk no Kevin the Movie
# 24817     55622                                Haruzora to Akizora
# 24818     55624                                       Icon's Story
# 24819     55625                                      Dynamic Venus
# 24821     55629  Iya na Kao sare nagara Opantsu Misete Moraitai...
# 24827     55640                            Wasure Hoshi no Volicia
# 24828     55643                           MY WIFE IS A DEMON QUEEN
# 24829     55644                        Dr. Stone: New World Part 2
# 24830     55646                                        Castlevania
# 24831     55647  One Piece: Dai Gekisen Tokushuu! Hangeki Doume...
# 24835     55651                      Tonikaku Kawaii: Joshikou-hen
# 24836     55652                        Bouken Tairiku Ania Kingdom
# 24837     55655                                       Cang Yuan Tu
# 24838     55656                                      Shashou Gu De
# 24839     55657                                  Ban Shen Zhi Jing
# 24841     55659                     Banjjagbanjjag Catch! Tiniping
# 24842     55660                    Alssongdalssong Catch! Tiniping
# 24861     55684                       Yong Sheng: Shi Nian Zhi Yue
# 24867     55690             Boku no Kokoro no Yabai Yatsu Season 2
# 24868     55691              Koumi-jima Shuu 7 de Umeru Mesu-tachi
# 24869     55692                        Feng Ling Yu Xiu 2nd Season
# 24870     55693                                   Zhen Yang Wushen
# 24871     55694                                       Gaishi Dizun
# 24874     55697                                       demon slayer
# 24875     55701                Kimetsu no Yaiba: Hashira Geiko-hen
# 24876     55702             Kimetsu no Yaiba: Purātorēninguāku-hen
# 24877     55704         Fire Emblem Heroes - Book III Ending Movie
# 24882     55709                               Boku to Roboko Movie
# 24884     55714                                       Retro Future
# 24886     55717  Dekisokonai to Yobareta Motoeiyuu wa Jikka kar...
# 24887     54693                               Observing Elena Evoy
# 24888     55719                   The Demon Queen Has a Death Wish
# 24889     55720                                  Tensura × Genyoha
# 24890     55721                             See You on Our Veranda
# 24891     55722                                    No More Princes
# 24892     55723            The Forgotten Princess Just Wants Peace
# 24893     55724                               Beauty and the Brawn
# 24828        Action, Adventure, Fantasy, Romance
# 24829                  Adventure, Comedy, Sci-Fi
# 24830  Action, Adventure, Drama, Fantasy, Horror
# 24831         Action, Adventure, Comedy, Fantasy
# 24835                            Comedy, Romance
# 24836                                  Adventure
# 24837                 Action, Adventure, Fantasy
# 24838                             Action, Comedy
# 24839                            Action, Fantasy
# 24841                                    Fantasy
# 24842                                    Fantasy
# 24861                 Action, Adventure, Fantasy
# 24867                            Comedy, Romance
# 24868                                     Hentai
# 24869                                  Adventure
# 24870                            Action, Fantasy
# 24871                 Action, Adventure, Fantasy
# 24874                                     Comedy
# 24875                            Action, Fantasy
# 24876                    Action, Comedy, Fantasy
# 24877                                    Fantasy
# 24882                             Comedy, Sci-Fi
# 24884                                Avant Garde
# 24886                 Action, Adventure, Fantasy
# 24887                           Fantasy, Romance
# 24888                           Fantasy, Romance
# 24889                            Comedy, Fantasy
# 24890                           Fantasy, Romance
# 24891                           Fantasy, Romance
# 24892                           Fantasy, Romance
# 24893                          Boys Love, Comedy
# 24894                                  Boys Love
# 24895                           Fantasy, Romance
# 24900             Comedy, Fantasy, Slice of Life
# 24901                 Action, Adventure, Fantasy
# 24902         Action, Adventure, Fantasy, Sci-Fi
#
#                                                 Synopsis     Type  \
# 24804  The globe has been taken over by alien beings ...    Movie
# 24805  Music video for the song Maehwa by Kim Yuna. S...      ONA
# 24806  Rather than being about Asahara's personal mys...      OVA
# 24807  As Shoko Asahara is depicted in a less embelli...      OVA
# 24808                                                         OVA
# 24809  He is the only light. A story about an office ...      ONA
# 24812  When a gamer and homebody starts the buff for ...      ONA
# 24813  The story centres on two married couples, Miha...      ONA
# 24815  Takeru Daigo is a boy living in Tokyo who does...    Movie
# 24817                                                       Movie
# 24818  A short animation by Maso Lin where the Window...      ONA
# 24819  A mysterious superheroine, Dynamic Venus (DV),...    Movie
# 24821                                                         OVA
# 24827                                                       Movie
# 24828  Xiang Ye was a fairly ordinary young man; afte...      ONA
# 24829                    Part 2 of Dr. Stone: New World.       TV
# 24830  A vampire slayer fights to save a city besiege...       TV
# 24831     This is the 8th recap special of the Wano arc.  Special
# 24835  Nasa, at the request of his former junior high...      ONA
# 24836                                                          TV
# 24837                                                         ONA
# 24838                                                         ONA
# 24839                                                         ONA
# 24841  The residents of Jewel Forest, Jewel Teeniepin...       TV
# 24842  Secret Key teeniepings appear in Harmony Town!...       TV
# 24861  In the majestic fantasy world, how does the pr...      ONA
# 24867    Second season of Boku no Kokoro no Yabai Yatsu.       TV
# 24868  Seiichi is bored with his routine life as a te...      OVA
# 24869                                                         ONA
# 24870                                                         ONA
# 24871                                                         ONA
# 24874                                                     Special
# 24875           Hashira Training Arc of Kimetsu no Yaiba       TV
# 24876                  Fourth season of Kimetsu no Yaiba       TV
# 24877  A short mini movie meant to celebrate the endi...      ONA
# 24882               The movie version of Boku to Roboko.    Movie
# 24884  A "remix version" of Modern with a soundtrack ...    Movie
# 24886  A boy named Allen was unable to receive the gi...       TV
# 24887  "If you're not my rival, why do I feel this wa...      ONA
# 24888  I wanted to die.. until I met him.\nAfter brea...      ONA
# 24889  A collaboration anime between Genjitsu no Yoha...      ONA
# 24890                                                         ONA
# 24891  html.serialization_informationFIN.\nジャンル\nFant...      ONA
# 24892  I'm the daughter of a Duke?!\nWhile locked up ...      ONA
# 24893  Haeun is a nobleman who falls hard for Dullseh...      ONA
# 24894  Wanna fake-date for 4 weeks?\nDojun's life at ...      ONA
# 24895  I just want to tell him how I feel!\nMina has ...      ONA
# 24900                                                         ONA
# 24901                                                         ONA
# 24902                                                         ONA
#
#            Producers Licensors               Studios       Source  \
# 24804                                                    Original
# 24805                                                   Web manga
# 24806                                                    Original
# 24807                                                    Original
# 24808                                                    Original
# 24809                                                    Original
# 24812                                                       Other
# 24813       Shueisha                Studio Hokiboshi        Manga
# 24815                                                    Original
# 24817                                                    Original
# 24818                                                    Original
# 24819                                    Studio Deen     Original
# 24821                                                       Other
# 24827                                                    Original
# 24828                                                   Web manga
# 24829                                                       Manga
# 24830                                                       Manga
# 24831                                                       Manga
# 24835                                     Seven Arcs        Manga
# 24836                                                    Original
# 24837          Youku                                    Web novel
# 24838          iQIYI                                    Web manga
# 24839          iQIYI                                    Web novel
# 24841                             SAMG Entertainment     Original
# 24842                             SAMG Entertainment     Original
# 24861                                                   Web novel
# 24867  Magic Capsule               Shin-Ei Animation        Manga
# 24868                                                     Unknown
# 24869                                                    Original
# 24870          Youku            Wonder Cat Animation      Unknown
# 24871                                                   Web novel
# 24874                                                     Unknown
# 24875                                       ufotable        Manga
# 24876                                                     Unknown
# 24877                                                        Game
# 24882                                                       Manga
# 24884                                                    Original
# 24886                                                 Light novel
# 24887                                                       Novel
# 24888                                                   Web manga
# 24889                                                    Original
# 24890                                                   Web novel
# 24891                                                   Web novel
# 24892                                                   Web novel
# 24893                                                       Manga
# 24894                                                   Web manga
# 24895                                                   Web manga
# 24900                                                   Web manga
# 24901                                                   Web novel
# 24902                                                   Web novel
#
#                                Rating  Favorites  Scored By  \
# 24804                R+ - Mild Nudity          0        NaN
# 24805  R - 17+ (violence & profanity)          0        NaN
# 24806                    G - All Ages          0        NaN
# 24807                    G - All Ages          0        NaN
# 24808                    G - All Ages          0        NaN
# 24809       PG-13 - Teens 13 or older          1        NaN
# 24812       PG-13 - Teens 13 or older          0        NaN
# 24813                     Rx - Hentai          0        NaN
# 24815                    G - All Ages          0        NaN
# 24817                    G - All Ages          0        NaN
# 24818       PG-13 - Teens 13 or older          0        NaN
# 24819  R - 17+ (violence & profanity)          0        NaN
# 24821                                          0        NaN
# 24827                                          1        NaN
# 24828       PG-13 - Teens 13 or older          0        NaN
# 24829       PG-13 - Teens 13 or older         70        NaN
# 24830  R - 17+ (violence & profanity)          0        NaN
# 24831       PG-13 - Teens 13 or older          1      320.0
# 24835       PG-13 - Teens 13 or older         39        NaN
# 24836                    G - All Ages          0        NaN
# 24837       PG-13 - Teens 13 or older          0        NaN
# 24838       PG-13 - Teens 13 or older          0        NaN
# 24839       PG-13 - Teens 13 or older          0        NaN
# 24841                   PG - Children          0        NaN
# 24842                   PG - Children          0        NaN
# 24861       PG-13 - Teens 13 or older          2        NaN
# 24882  https://cdn.myanimelist.net/images/anime/1277/...
# 24884  https://cdn.myanimelist.net/images/anime/1360/...
# 24886  https://cdn.myanimelist.net/images/anime/1293/...
# 24887  https://cdn.myanimelist.net/images/anime/1526/...
# 24888  https://cdn.myanimelist.net/images/anime/1527/...
# 24889  https://cdn.myanimelist.net/images/anime/1615/...
# 24890  https://cdn.myanimelist.net/img/sp/icon/apple-...
# 24891  https://cdn.myanimelist.net/img/sp/icon/apple-...
# 24892  https://cdn.myanimelist.net/images/anime/1887/...
# 24893  https://cdn.myanimelist.net/images/anime/1269/...
# 24894  https://cdn.myanimelist.net/images/anime/1443/...
# 24895  https://cdn.myanimelist.net/images/anime/1621/...
# 24900  https://cdn.myanimelist.net/images/anime/1386/...
# 24901  https://cdn.myanimelist.net/images/anime/1383/...
# 24902  https://cdn.myanimelist.net/images/anime/1130/...

# %%
# Select only the genres and synopsis columns
subset = animedf_clean[['Genres', 'Synopsis']].apply(lambda x: x=='')

# Create a boolean DataFrame where True indicates a missing value
missing = subset.astype(int)

# Create the heatmap
plt.figure(figsize=(20,20))
sns.heatmap(missing, cbar=False, cmap='RdYlGn_r')
plt.title('Heatmap of missing values in genres and synopsis')
plt.show()

#Key finding: We notice a HUGE clustering at a specific area in Synopsis while genres seem randomly distributed. This indicates that are null values aren't distributed at random for that column. let's look deeper into this.
#Green is True, Red is False

# %%
animedf_clean[17222:18726].tail(50) #review the range of indices by splicing.
# Out:
#        anime_id                                               Name  \
# 20239     47527        Wang Xiong Li Xiong Meiwan Meiliao De Gushi
# 20240     47528  Wang Xiong Li Xiong Meiwan Meiliao De Gushi Fa...
# 20241     47530                                  Kaixin Dongwuyuan
# 20242     47532                              Jinpai Bang Bang Bang
# 20243     47533               Jinpai Bang Bang Bang: Jia Yu Xiwang
# 20244     47534             Jinpai Bang Bang Bang: Ai Yu Mengxiang
# 20245     47535                                      Yu Jian Tuzki
# 20246     47537         Inou no AICis: ESP & High School Detective
# 20247     47538                     Haishang Si Lu: Nan Zhubao Bao
# 20248     47541                             Chaoji Xiaoxiong BOOMi
# 20249     47542                           Sazae-san: Valentine-hen
# 20251     47544                                            Ba Nian
# 20252     47545                                       Taoqi Huaxue
# 20253     47546                                 Maolu Xiao Zhentan
# 20254     47547                                     Shentan Dadang
# 20255     47548                Doupo Cangqiong: Q Ban Xiao Juchang
# 20256     47549                                      5 Dong 32 Hao
# 20257     47550                           5 Dong 32 Hao: Hesui Fan
# 20258     47551                                      Guoshu Leyuan
# 20259     47552                  Qihuan Lucheng: Mao Mao Shu Laile
# 20260     47553                            Dan Ding Dang Lixian Ji
# 20261     47554                         Tunshu Zhen Lequ Sanzijing
# 20262     47555                                 Xiao Yu Er Qiyu Ji
# 20263     47556                             Guai Baobao Ting Gushi
# 20264     47557                                      Xiao Gou Pipi
# 20265     47558                                    Haha Da Maoxian
# 20266     47559                                     Shenye Yu Tang
# 20267     47560                               Yu Laoban No Richang
# 20268     47563                            Xiao Laba: Tanxian Qiyu
# 20269     47564                                Hulu Xiang Dingdang
# 20270     47565                             Guoshanche Shou Luo Li
# 20260        NaN  https://cdn.myanimelist.net/images/anime/1526/...
# 20261        NaN  https://cdn.myanimelist.net/images/anime/1432/...
# 20262        NaN  https://cdn.myanimelist.net/images/anime/1088/...
# 20263        NaN  https://cdn.myanimelist.net/images/anime/1267/...
# 20264        NaN  https://cdn.myanimelist.net/images/anime/1529/...
# 20265        NaN  https://cdn.myanimelist.net/images/anime/1305/...
# 20266        NaN  https://cdn.myanimelist.net/images/anime/1934/...
# 20267        NaN  https://cdn.myanimelist.net/images/anime/1399/...
# 20268        NaN  https://cdn.myanimelist.net/images/anime/1154/...
# 20269        NaN  https://cdn.myanimelist.net/images/anime/1305/...
# 20270        NaN  https://cdn.myanimelist.net/images/anime/1220/...
# 20271        NaN  https://cdn.myanimelist.net/images/anime/1450/...
# 20272        NaN  https://cdn.myanimelist.net/images/anime/1616/...
# 20273        NaN  https://cdn.myanimelist.net/images/anime/1908/...
# 20274        NaN  https://cdn.myanimelist.net/images/anime/1980/...
# 20275        NaN  https://cdn.myanimelist.net/images/anime/1593/...
# 20276        NaN  https://cdn.myanimelist.net/images/anime/1420/...
# 20277        NaN  https://cdn.myanimelist.net/images/anime/1301/...
# 20278        NaN  https://cdn.myanimelist.net/images/anime/1513/...
# 20279        NaN  https://cdn.myanimelist.net/images/anime/1533/...
# 20280        NaN  https://cdn.myanimelist.net/images/anime/1639/...
# 20281        NaN  https://cdn.myanimelist.net/images/anime/1502/...
# 20282        NaN  https://cdn.myanimelist.net/images/anime/1950/...
# 20283        NaN  https://cdn.myanimelist.net/images/anime/1020/...
# 20284        NaN  https://cdn.myanimelist.net/images/anime/1377/...
# 20285        NaN  https://cdn.myanimelist.net/images/anime/1797/...
# 20286        NaN  https://cdn.myanimelist.net/images/anime/1505/...
# 20287        NaN  https://cdn.myanimelist.net/images/anime/1788/...
# 20288        NaN  https://cdn.myanimelist.net/images/anime/1811/...
# 20289        NaN  https://cdn.myanimelist.net/images/anime/1529/...

# %% [markdown]
# While it seems that the synopsis is clustered under some areas compared to genres, it can be concluded from this observation up close that the genres and synopsis especially are missing at random. Certain areas such as scores, favorites, and scored-by can be missing. Or we have little to no user feedback on these animes- either because they are not well known, old, or just undocumented. I also predict/assume some types of animes are obscure or rare to find, such as if they are internet-based, released through home video formats (i.e. non-streamable online), or an "original" source. It isn't fully influenced by genre since they significantly vary from genre to genre since it can be a comedy, fantasy, action, romance, or even a mix of these and they are common genres too.
#
# From this observation, the best course of action is to ignore missing areas for the genres and synopsis areas while focusing on the other relevant features (Name, studio, type, rating etc), since we need information from there to create the content-based recommendation system. We have too many null values that we can't easily remove without skewing or making the data biased (13.5% and 20.04% -> both greater than 10%).

# %% [markdown]
# With additional review, it is noticeable within the cluster that there is missing data for all text-based information and scores. Since it's only 1264 entries out of 24905. Only 6% of the data is COMPLETELY missing entries. These entries will be dropped.

# %%
missing_values = animedf_clean[(animedf_clean['Score'].isnull()) & (animedf_clean['Genres'] == '') & (animedf_clean['Synopsis'] == '') & (animedf_clean['Producers']== '') & (animedf_clean['Licensors'] == '') & (animedf_clean['Studios']=='')].index
missing_values
# Out:
# Index([ 5023,  5146,  5869,  6111,  8499,  9287, 10275, 10764, 10943, 11020,
#        ...
#        23825, 23846, 23891, 23915, 24013, 24327, 24408, 24409, 24519, 24564],
#       dtype='int64', length=1264)

# %%
#remove these missing entries from animedf_clean:
animedf_clean = animedf_clean.drop(missing_values)
animedf_clean
# Out:
#        anime_id                             Name             English name  \
# 0             1                     Cowboy Bebop             Cowboy Bebop
# 1             5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2             6                           Trigun                   Trigun
# 3             7               Witch Hunter Robin       Witch Hunter Robin
# 4             8                   Bouken Ou Beet   Beet the Vandel Buster
# ...         ...                              ...                      ...
# 24894     55725                    4 Week Lovers            4 Week Lovers
# 24895     55726                     Die, Please!             Die, Please!
# 24900     55731                      Wu Nao Monu              Wu Nao Monu
# 24901     55732              Bu Xing Si: Yuan Qi              Blader Soul
# 24902     55733                      Di Yi Xulie          The First Order
#
#        Score                                Genres  \
# 0       8.75         Action, Award Winning, Sci-Fi
# 1       8.38                        Action, Sci-Fi
# 2       8.22             Action, Adventure, Sci-Fi
# 3       7.25  Action, Drama, Mystery, Supernatural
# 4       6.94      Adventure, Fantasy, Supernatural
# ...      ...                                   ...
# 24894    NaN                             Boys Love
# 24895    NaN                      Fantasy, Romance
# 24900    NaN        Comedy, Fantasy, Slice of Life
# 24901    NaN            Action, Adventure, Fantasy
# 24902    NaN    Action, Adventure, Fantasy, Sci-Fi
#
#                                                 Synopsis   Type  \
# 0      Crime is timeless. By the year 2071, humanity ...     TV
# 1      Another day, another bounty—such is the life o...  Movie
# 2      Vash the Stampede is the man with a $$60,000,0...     TV
# 3      Robin Sena is a powerful craft user drafted in...     TV
# 4      It is the dark century and the people are suff...     TV
# ...                                                  ...    ...
# 24894  Wanna fake-date for 4 weeks?\nDojun's life at ...    ONA
# 24895  I just want to tell him how I feel!\nMina has ...    ONA
# 24900                                                       ONA
# 24901                                                       ONA
# 24902                                                       ONA
#
#                                                Producers  \
# 0                                          Bandai Visual
# 1                                 Sunrise, Bandai Visual
# 2                                   Victor Entertainment
# 3      Bandai Visual, Dentsu, Victor Entertainment, T...
# 4                                       TV Tokyo, Dentsu
# ...                                                  ...
# 24894
# 24895
# 24900
# 24901
# 24902
#
#                                   Licensors         Studios     Source  \
# 0          Funimation, Bandai Entertainment         Sunrise   Original
# 1               Sony Pictures Entertainment           Bones   Original
# 2      Funimation, Geneon Entertainment USA        Madhouse      Manga
# 3          Funimation, Bandai Entertainment         Sunrise   Original
# 4                  Illumitoon Entertainment  Toei Animation      Manga
# ...                                     ...             ...        ...
# 24894                                                        Web manga
# 24895                                                        Web manga
# 24900                                                        Web manga
# 24901                                                        Web novel
# 24902                                                        Web novel
#
#                                Rating  Favorites  Scored By  \
# 0      R - 17+ (violence & profanity)      78525   914193.0
# 1      R - 17+ (violence & profanity)       1448   206248.0
# 2           PG-13 - Teens 13 or older      15035   356739.0
# 3           PG-13 - Teens 13 or older        613    42829.0
# 4                       PG - Children         14     6413.0
# ...                               ...        ...        ...
# 24894                                          0        NaN
# 24895                    G - All Ages          0        NaN
# 24900       PG-13 - Teens 13 or older          0        NaN
# 24901       PG-13 - Teens 13 or older          0        NaN
# 24902       PG-13 - Teens 13 or older          0        NaN
#
#                                                Image URL
# 0      https://cdn.myanimelist.net/images/anime/4/196...
# 1      https://cdn.myanimelist.net/images/anime/1439/...
# 2      https://cdn.myanimelist.net/images/anime/7/203...
# 3      https://cdn.myanimelist.net/images/anime/10/19...
# 4      https://cdn.myanimelist.net/images/anime/7/215...
# ...                                                  ...
# 24894  https://cdn.myanimelist.net/images/anime/1443/...
# 24895  https://cdn.myanimelist.net/images/anime/1621/...
# 24900  https://cdn.myanimelist.net/images/anime/1386/...
# 24901  https://cdn.myanimelist.net/images/anime/1383/...
# 24902  https://cdn.myanimelist.net/images/anime/1130/...
#
# [20881 rows x 15 columns]

# %% [markdown]
# #### 2.) Feature Engineering

# %% [markdown]
# Next, we perform feature generation/engineering to make a "Tags" column and "Popularity Metrics". We merge the "Synopsis", "Genres", and other relevant text columns to create Tags. While normalizing average scores and favorites columns and calculate the popularity score.

# %%
animedf_clean['Synopsis'] = animedf_clean['Synopsis'].str.replace('\n', '')

tags = (animedf_clean['Genres'] + " " + animedf_clean['Synopsis'] + " " + animedf_clean['Type'] + " " + animedf_clean['Producers'] +  " " + animedf_clean['Studios'] +  " " + animedf_clean['Source'] +  " " + animedf_clean['Rating'])
animedf_clean['Tags'] = tags

animedf_clean['Tags']
# Out:
# 0        Action, Award Winning, Sci-Fi Crime is timeles...
# 1        Action, Sci-Fi Another day, another bounty—suc...
# 2        Action, Adventure, Sci-Fi Vash the Stampede is...
# 3        Action, Drama, Mystery, Supernatural Robin Sen...
# 4        Adventure, Fantasy, Supernatural It is the dar...
#                                ...
# 24894    Boys Love Wanna fake-date for 4 weeks?Dojun's ...
# 24895    Fantasy, Romance I just want to tell him how I...
# 24900    Comedy, Fantasy, Slice of Life  ONA   Web mang...
# 24901    Action, Adventure, Fantasy  ONA   Web novel PG...
# 24902    Action, Adventure, Fantasy, Sci-Fi  ONA   Web ...
# Name: Tags, Length: 20881, dtype: object

# %% [markdown]
# We have NaN values that we need to deal with since NLTK will have issues handling them. Lets look deeper into this and replace it as a certain value to avoid the issues.

# %%
animedf_clean.loc[24902]
# Out:
# anime_id                                                    55733
# Name                                                  Di Yi Xulie
# English name                                      The First Order
# Score                                                         NaN
# Genres                         Action, Adventure, Fantasy, Sci-Fi
# Synopsis
# Type                                                          ONA
# Producers
# Licensors
# Studios
# Source                                                  Web novel
# Rating                                  PG-13 - Teens 13 or older
# Favorites                                                       0
# Scored By                                                     NaN
# Image URL       https://cdn.myanimelist.net/images/anime/1130/...
# Tags            Action, Adventure, Fantasy, Sci-Fi  ONA   Web ...
# Name: 24902, dtype: object

# %% [markdown]
# Now that we have created a tags column containing the most important information on an anime, we use NLP techniques. But first:
#
# 1.) Set everything to lowercase
#
# 2.) Remove unnecessary symbols and spaces. However, we should keep numbers since we need it for rating.
#
# 3.) Remove trailing whitespace
#
# 4.) Remove stop words in each tag entry.
#
# 5.) Lemmatize each tag entry.

# %%
#1.) Set entries to lowercase
animedf_clean['Tags'] = animedf_clean['Tags'].str.lower()

#2.) Remove unnecessary symbols and  3.) extra spaces
animedf_clean['Tags'] = animedf_clean['Tags'].str.replace(r'[^A-Za-z0-9_\s]+', ' ', regex=True)
animedf_clean['Tags'] = animedf_clean['Tags'].str.replace(r'\s+', ' ', regex=True).str.strip()

#4.) Remove stop-words
stopwords = nltk.corpus.stopwords.words('english')
animedf_clean['Tags'] = animedf_clean['Tags'].apply(lambda x: ' '.join([word for word in nltk.word_tokenize(x) if word not in stopwords]))

#5.) Lemmatization
lemmatizer = nltk.WordNetLemmatizer()
animedf_clean['Tags'] = animedf_clean['Tags'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in nltk.word_tokenize(x)]))

# %% [markdown]
# Now lets create the Popularity Metrics column:
#
# 1.) Normalize average scores to be in the range 0-1.
#
# 2.) Normalize favorites to be in the range 0-1.

# %%
#Extract from animedf_clean the scores column and convert it into a list, then normalize. 

scores = animedf_clean['Score'].to_numpy().reshape(-1, 1) 
normalized_scores = MinMaxScaler().fit_transform(scores)

#Do the same process for Favorites.
favorites = animedf_clean['Favorites'].to_numpy().reshape(-1,1)
normalized_favorites = MinMaxScaler().fit_transform(favorites)

# %% [markdown]
# #### 3.) Vectorization (Using TFIDF and Cosine Similarity - Content Based)

# %%
#Construct TFIDF Matrix
tfidf = TfidfVectorizer(norm='l1', use_idf=False, smooth_idf=True, 
                             sublinear_tf=True, max_features=5000, 
                             ngram_range=(1, 2))

tfidf_matrix =  tfidf.fit_transform(animedf_clean['Tags'])
cosine_similarity = cosine_similarity(tfidf_matrix)
print(cosine_similarity.shape)
#make cosine_similarity matrix into a data frame format:
cosine_similarity_df = pd.DataFrame(cosine_similarity, index=animedf_clean['English name'], columns=animedf_clean['English name'])
# Out:
# (20881, 20881)

# %%
cosine_similarity_df
# Out:
# English name             Cowboy Bebop  Cowboy Bebop: The Movie    Trigun  \
# English name
# Cowboy Bebop                 1.000000                 0.310415  0.142422
# Cowboy Bebop: The Movie      0.310415                 1.000000  0.158148
# Trigun                       0.142422                 0.158148  1.000000
# Witch Hunter Robin           0.155382                 0.099488  0.220054
# Beet the Vandel Buster       0.055802                 0.040420  0.106898
# ...                               ...                      ...       ...
# 4 Week Lovers                0.082503                 0.033644  0.109623
# Die, Please!                 0.017906                 0.000000  0.036661
# Wu Nao Monu                  0.035105                 0.037086  0.287811
# Blader Soul                  0.021661                 0.038745  0.285315
# The First Order              0.079664                 0.098742  0.323493
#
# English name             Witch Hunter Robin  Beet the Vandel Buster  \
# English name
# Cowboy Bebop                       0.155382                0.055802
# Cowboy Bebop: The Movie            0.099488                0.040420
# Trigun                             0.220054                0.106898
# Witch Hunter Robin                 1.000000                0.142889
# Beet the Vandel Buster             0.142889                1.000000
# ...                                     ...                     ...
# 4 Week Lovers                      0.022442                0.056978
# Die, Please!                       0.021364                0.036161
# Wu Nao Monu                        0.244083                0.104679
# Blader Soul                        0.280845                0.102650
# The First Order                    0.258219                0.094380
#
# The First Order                      0.035978       0.109535      0.139032
#
# English name             Wu Nao Monu  Blader Soul  The First Order
# English name
# Cowboy Bebop                0.035105     0.021661         0.079664
# Cowboy Bebop: The Movie     0.037086     0.038745         0.098742
# Trigun                      0.287811     0.285315         0.323493
# Witch Hunter Robin          0.244083     0.280845         0.258219
# Beet the Vandel Buster      0.104679     0.102650         0.094380
# ...                              ...          ...              ...
# 4 Week Lovers               0.228063     0.119132         0.109535
# Die, Please!                0.217110     0.151214         0.139032
# Wu Nao Monu                 1.000000     0.606996         0.558094
# Blader Soul                 0.606996     1.000000         0.877388
# The First Order             0.558094     0.877388         1.000000
#
# [20881 rows x 20881 columns]

# %% [markdown]
# #### 4.) Vectorization (Using Collab filtering Popularity Based Recommendation)

# %%
popularity_metric = (0.6 * normalized_scores) + (0.4 * normalized_favorites) #weights that we can tune
popularity_metric_df = pd.DataFrame(popularity_metric, index=animedf_clean['English name'], columns=['Popularity Score'])

popularity_metric_df
# Out:
#                          Popularity Score
# English name
# Cowboy Bebop                     0.715378
# Cowboy Bebop: The Movie          0.543075
# Trigun                           0.554810
# Witch Hunter Robin               0.448023
# Beet the Vandel Buster           0.421267
# ...                                   ...
# 4 Week Lovers                         NaN
# Die, Please!                          NaN
# Wu Nao Monu                           NaN
# Blader Soul                           NaN
# The First Order                       NaN
#
# [20881 rows x 1 columns]

# %% [markdown]
# #### 5.) Combining content and collaborative based filterings to make a hybrid weighted recommendation system:

# %%
#Normalize again by combining the two data frames
hybrid = popularity_metric_df.merge(cosine_similarity_df, on=animedf_clean['English name'])
hybrid = hybrid.set_index("key_0")

# %%
normalized_hybrid = MinMaxScaler().fit_transform(hybrid)
normalized_hybrid_df = pd.DataFrame(normalized_hybrid, index=hybrid.index, columns=hybrid.columns)

normalized_hybrid_df
# Out:
#                          Popularity Score  Cowboy Bebop  \
# key_0
# Cowboy Bebop                     0.715320      1.000000
# Cowboy Bebop: The Movie          0.542982      0.310415
# Trigun                           0.554719      0.142422
# Witch Hunter Robin               0.447911      0.155382
# Beet the Vandel Buster           0.421149      0.055802
# ...                                   ...           ...
# 4 Week Lovers                         NaN      0.082503
# Die, Please!                          NaN      0.017906
# Wu Nao Monu                           NaN      0.035105
# Blader Soul                           NaN      0.021661
# The First Order                       NaN      0.079664
#
#                          Cowboy Bebop: The Movie    Trigun  \
# key_0
# Cowboy Bebop                            0.310415  0.142422
# Cowboy Bebop: The Movie                 1.000000  0.158148
# Trigun                                  0.158148  1.000000
# Witch Hunter Robin                      0.099488  0.220054
# Beet the Vandel Buster                  0.040420  0.106898
# ...                                          ...       ...
# 4 Week Lovers                           0.033644  0.109623
# Die, Please!                            0.000000  0.036661
# Wu Nao Monu                             0.037086  0.287811
# Blader Soul                             0.038745  0.285315
# The First Order                         0.098742  0.323493
#
#                          Witch Hunter Robin  Beet the Vandel Buster  \
# key_0
# Cowboy Bebop                       0.155382                0.055802
# Cowboy Bebop: The Movie            0.099488                0.040420
# Trigun                             0.220054                0.106898
# Witch Hunter Robin                 1.000000                0.142889
# Beet the Vandel Buster             0.142889                1.000000
# Wu Nao Monu                          0.112365       0.228063      0.217110
# Blader Soul                          0.039130       0.119132      0.151214
# The First Order                      0.035978       0.109535      0.139032
#
#                          Wu Nao Monu  Blader Soul  The First Order
# key_0
# Cowboy Bebop                0.035105     0.021661         0.079664
# Cowboy Bebop: The Movie     0.037086     0.038745         0.098742
# Trigun                      0.287811     0.285315         0.323493
# Witch Hunter Robin          0.244083     0.280845         0.258219
# Beet the Vandel Buster      0.104679     0.102650         0.094380
# ...                              ...          ...              ...
# 4 Week Lovers               0.228063     0.119132         0.109535
# Die, Please!                0.217110     0.151214         0.139032
# Wu Nao Monu                 1.000000     0.606996         0.558094
# Blader Soul                 0.606996     1.000000         0.877388
# The First Order             0.558094     0.877388         1.000000
#
# [21331 rows x 20882 columns]

# %%
#Fill NaN values with 0
normalized_hybrid_df = normalized_hybrid_df.fillna(0)

# %% [markdown]
# Take the averages for all the similarity scores based on row index:

# %%
normalized_hybrid_df['Similarity Score Avg'] =  normalized_hybrid_df.iloc[:, 1:].mean(axis=1)

normalized_hybrid_df_cl = normalized_hybrid_df.iloc[:, [0,-1]]
normalized_hybrid_df_cl.reset_index(inplace=True)

# %%
print(normalized_hybrid_df_cl.columns)
# Out:
# Index(['key_0', 'Popularity Score', 'Similarity Score Avg'], dtype='object')

# %% [markdown]
# final score = (weight * popularity score) + (weight * similarity score average)

# %%
#apply the final score formula:
normalized_hybrid_df_cl['Final Score'] = (0.5 * normalized_hybrid_df_cl['Popularity Score']) + (0.5 * normalized_hybrid_df_cl['Similarity Score Avg'])
normalized_hybrid_df_cl
# Out:
# C:\Users\saiya\AppData\Local\Temp\ipykernel_1980\3415819721.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   normalized_hybrid_df_cl['Final Score'] = (0.5 * normalized_hybrid_df_cl['Popularity Score']) + (0.5 * normalized_hybrid_df_cl['Similarity Score Avg'])
#                          key_0  Popularity Score  Similarity Score Avg  \
# 0                 Cowboy Bebop          0.715320              0.056168
# 1      Cowboy Bebop: The Movie          0.542982              0.051594
# 2                       Trigun          0.554719              0.105259
# 3           Witch Hunter Robin          0.447911              0.123876
# 4       Beet the Vandel Buster          0.421149              0.077436
# ...                        ...               ...                   ...
# 21326            4 Week Lovers          0.000000              0.048652
# 21327             Die, Please!          0.000000              0.058747
# 21328              Wu Nao Monu          0.000000              0.171218
# 21329              Blader Soul          0.000000              0.162720
# 21330          The First Order          0.000000              0.161937
#
#        Final Score
# 0         0.385744
# 1         0.297288
# 2         0.329989
# 3         0.285893
# 4         0.249292
# ...            ...
# 21326     0.024326
# 21327     0.029374
# 21328     0.085609
# 21329     0.081360
# 21330     0.080969
#
# [21331 rows x 4 columns]

# %%
normalized_hybrid_df_cl = normalized_hybrid_df_cl.drop(columns=['Popularity Score', 'Similarity Score Avg'], axis=1)

# %%
normalized_hybrid_df_cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21331 entries, 0 to 21330
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   key_0        21331 non-null  object
#  1   Final Score  21331 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 333.4+ KB

# %%
#Use fuzzy-wuzzy in case user input is slightly off from the full anime name and transfer everything into a list
anime = input('Enter a list of anime you like (separated by commas): ')
listanime = anime.split(',')

matches = []
for anime_name in listanime:
    match = process.extract(anime_name, animedf_clean['English name'], limit=3, scorer=fuzz.ratio)
    matches.append(match)


#user dictionary input list
input_list = {}

for innerlist in matches:
    for values in innerlist:
        anime_name, score, index = values
        if score >= 70: #making sure its the exact anime we look for. The higher the score, the more accurate it is.
            filtered_df = normalized_hybrid_df_cl[normalized_hybrid_df_cl['key_0'] == anime_name]['key_0']
            value = filtered_df.values[0]

            filtered_df2 = normalized_hybrid_df_cl[normalized_hybrid_df_cl['key_0'] == anime_name]['Final Score']
            key = filtered_df2.values[0]
            input_list[value] = key
            break

#Calculate the average final score of the dictionary:
average_score = sum(input_list.values()) / len(input_list) 
print(average_score)


#Take the absolute difference with the final score and user's average score
normalized_hybrid_df_cl['Difference']= abs(normalized_hybrid_df_cl['Final Score'] - average_score)
normalized_hybrid_df_cl['Difference'] = normalized_hybrid_df_cl['Difference'].sort_values(ascending=True)

print(f'Top animes similar to your choices:')
recommended_animes = normalized_hybrid_df_cl.loc[~normalized_hybrid_df_cl.index.isin(input_list.keys())]

#To get the most accurate recommendations, we find the smallest difference. 
final_recommendation = recommended_animes.nsmallest(30,'Difference')
final_recommendation
# Out:
# Enter a list of anime you like (separated by commas):  blue exorcist
# 0.29938221816472
# Top animes similar to your choices:
#                                                    key_0  Final Score  \
# 6002                                       Blue Exorcist     0.299382
# 7986    Love, Chunibyo & Other Delusions!: Rikka Version     0.299381
# 8301                                        Noragami OVA     0.299387
# 8071                 Naruto Shippuden: Sunny Side Battle     0.299392
# 7202                                 AKB0048: Next Stage     0.299396
# 14110                        Is the Order a Rabbit?? OVA     0.299350
# 7901                     Yozakura Quartet: Tsuki ni Naku     0.299346
# 5485   Reborn! Here Comes a Vongola Family-Style Scho...     0.299427
# 15352                 Dragon Quest: The Adventure of Dai     0.299335
# 13780                                         Yuru Yuri,     0.299332
# 6286   Doraemon: Nobita and the Steel Troops - The Ne...     0.299441
# 16232                                      Shadows House     0.299313
# 5776                          Maid Sama!: It's an Extra!     0.299301
# 7316                                     Saint☆Young Men     0.299263
# 6668                                      Kokoro Connect     0.299504
# 2436                                   Black Cat Special     0.299508
# 1750   Slam Dunk: Zenkoku Seiha Da! - Sakuragi Hanamichi     0.299233
# 7596                      Saiyuuki Gaiden: Kouga no Shou     0.299547
# 13153                   Fox Spirit Matchmaker 5th Season     0.299190
# 11537                           One Piece: Heart of Gold     0.299595
# 13393                               Zoku Owarimonogatari     0.299599
# 10580                            Himouto! Umaru-chan OVA     0.299603
# 2953                             Kiddy Grade: Truth Dawn     0.299606
# 6764                          YuruYuri: Happy Go Lily ♪♪     0.299617
# 1214                                      Urusei Yatsura     0.299633
# 14122                      Majimoji Rurumo: Kanketsu-hen     0.299634
# 12124                            Days: Touin Gakuen-sen!     0.299637
# 832                                          Angel's Egg     0.299126
# 18826                                Goodbye, Don Glees!     0.299122
# 4562            Tenjoubito to Akutobito Saigo no Tatakai     0.299647
#
#        Difference
# 6002     0.000000
# 7986     0.000002
# 8301     0.000005
# 8071     0.000010
# 7202     0.000014
# 14110    0.000032
# 7901     0.000036
# 5485     0.000045
# 15352    0.000047
# 13780    0.000051
# 6286     0.000059
# 16232    0.000070
# 5776     0.000081
# 7316     0.000119
# 6668     0.000122
# 2436     0.000126
# 1750     0.000149
# 7596     0.000164
# 13153    0.000192
# 11537    0.000213
# 13393    0.000217
# 10580    0.000221
# 2953     0.000224
# 6764     0.000234
# 1214     0.000251
# 14122    0.000252
# 12124    0.000255
# 832      0.000256
# 18826    0.000261
# 4562     0.000265

# %% [markdown]
# #### Image Display Version

# %%
from IPython.display import Image, display

for anime_name in final_recommendation['key_0']:
    image_url = animedf_clean[animedf_clean['English name'] == anime_name]['Image URL'].values[0]
    display(Image(url=image_url))
# Out:
# <img src="https://cdn.myanimelist.net/images/anime/10/75195.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/2/56167.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/7/77177.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/1047/91638.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/11/44450.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/1684/101030.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/3/49489.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/7/27088.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/1499/109126.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/1138/99547.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/7/72436.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/1424/113342.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/3/29438.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/3/53249.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/2/39665.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/5/22527.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/12/31929.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/10/45795.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/5/88318.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/1673/120160.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/1022/96168.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/7/76826.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/11/56967.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/8/75174.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/9/17573.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/1375/109425.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/12/88505.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/11/63181.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/1568/117628.jpg"/>
# <img src="https://cdn.myanimelist.net/images/anime/4/28140.jpg"/>

# %% [markdown]
# #### Observations:

# %% [markdown]
# The more popular and well-known an anime is and within a certain common genre, the easier it is to make relevant recommendations based on user input. The same goes for sparse user inputs as well. However, if you consistently give low and less-rated animes in the list consistently of a certain genre, it may not make the best recommendations preferred for the user. May need to ask users to input genre preferences.
